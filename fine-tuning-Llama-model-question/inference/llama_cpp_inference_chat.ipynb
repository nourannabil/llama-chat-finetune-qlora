# %% [markdown]
# # Llama.cpp python inference
# https://llama-cpp-python.readthedocs.io/en/latest/

# %% [markdown]
# Inference over our trained ascii adapters

# %%
#pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 MB 19.4 MB/s  0:00:03 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.16-cp311-cp311-macosx_15_0_arm64.whl size=3803182 sha256=ac948a73017efef6ceb492cc6e4e49c29cb3155509bfaf449ec06221a42d6a27
#   Stored in directory: /Users/mohammedenbah/Library/Caches/pip/wheels/d8/5b/e5/a7d4b5765da347d314e8155197440c9995a962f8e4a5f52b23
# Successfully built llama-cpp-python
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [llama-cpp-python]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_cpp import Llama

# %%
llm = Llama(
      model_path="/Users/mohammedenbah/Desktop/ML Projects/fine-tuning-Llama-model-question/model-gguf/meta-llama-3.1-8b-instruct.Q4_K_M.gguf",
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M2 Pro) - 10922 MiB free
# llama_model_loader: loaded meta data with 32 key-value pairs and 291 tensors from /Users/mohammedenbah/Desktop/ML Projects/fine-tuning-Llama-model-question/model-gguf/meta-llama-3.1-8b-instruct.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Unsloth_Gguf_P1Jl5Rxx
# llama_model_loader: - kv   3:                       general.quantized_by str              = Unsloth
# llama_model_loader: - kv   4:                         general.size_label str              = 8.0B
# ...

# %%
llm.create_chat_completion(
      messages = [
        {"role": "user", "content": "who is partnering with Kamala Harris on the Democratic ticket In the 2024 presidential race?"},
      ]
)
# Out:
# Llama.generate: 30 prefix-match hit, remaining 24 prompt tokens to eval
# llama_perf_context_print:        load time =    5479.30 ms
# llama_perf_context_print: prompt eval time =    4552.77 ms /    24 tokens (  189.70 ms per token,     5.27 tokens per second)
# llama_perf_context_print:        eval time =     720.40 ms /     3 runs   (  240.13 ms per token,     4.16 tokens per second)
# llama_perf_context_print:       total time =    5277.48 ms /    27 tokens
# llama_perf_context_print:    graphs reused =          2
# {'id': 'chatcmpl-c3e031f8-4499-4207-848c-87aef55a5691',
#  'object': 'chat.completion',
#  'created': 1774023732,
#  'model': '/Users/mohammedenbah/Desktop/ML Projects/fine-tuning-Llama-model-question/model-gguf/meta-llama-3.1-8b-instruct.Q4_K_M.gguf',
#  'choices': [{'index': 0,
#    'message': {'role': 'assistant', 'content': 'Tim Walz'},
#    'logprobs': None,
#    'finish_reason': 'stop'}],
# ...
